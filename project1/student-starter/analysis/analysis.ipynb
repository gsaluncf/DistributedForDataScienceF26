# %% [markdown]
# # AdFlow — Analyst Report
# **Project 1 · Distributed Systems for Data Science · New College of Florida**
#
# This notebook contains:
# 1. **Pipeline Evidence** — proof the full SQS → Lambda → DynamoDB path ran successfully.
# 2. **Q1 Results Analysis** — auction winner breakdown, overall and by content category.
# 3. **Q2 Code Reflection** — discussion of distributed architecture challenges.

# %% [markdown]
# ---
# ## Section 1: Pipeline Evidence
# _This section is not graded for analysis quality — it is proof the pipeline ran end-to-end._

# %%
import boto3
from decimal import Decimal
from collections import Counter
import pandas as pd

# ── Replace with your deployed student ID ──────────────────────────────────
STUDENT_ID = "macfarlane"          # e.g. 'gsalu'
REGION     = "us-east-1"
TABLE_NAME = f"adflow-{STUDENT_ID}-results"
# ────────────────────────────────────────────────────────────────────────────

dynamodb = boto3.resource("dynamodb", region_name=REGION)
table    = dynamodb.Table(TABLE_NAME)

results  = []
response = table.scan()
results.extend(response["Items"])

while "LastEvaluatedKey" in response:
    response = table.scan(ExclusiveStartKey=response["LastEvaluatedKey"])
    results.extend(response["Items"])

# Convert Decimal → float for analysis
for item in results:
    for key in ["winning_bid_amount", "winning_score", "score_margin"]:
        if key in item:
            item[key] = float(item[key])

print(f"Loaded {len(results)} records from DynamoDB table '{TABLE_NAME}'")
# Out:
# Loaded 22470 records from DynamoDB table 'adflow-macfarlane-results'

# %%
# Auction wins per advertiser (overall)
df = pd.DataFrame(results)
overall_wins = df["winning_advertiser_id"].value_counts()
print("=== Overall Wins by Advertiser ===")
print(overall_wins.to_string())
# Out:
# === Overall Wins by Advertiser ===
# winning_advertiser_id
# adv_fintech_01       5986
# adv_travel_01        4019
# adv_insurance_01     3880
# adv_streaming_01     3010
# adv_fastfood_01      2056
# adv_energy_01        1395
# adv_sportswear_01     782
# adv_beauty_01         745
# adv_gaming_01         418
# adv_sportswear_02     158
# adv_energy_02          12
# adv_fintech_02          9

# %%
# Screenshot of the test apparatus goes here.
# Save it as screenshots/burst_run.png and it will appear below.
from IPython.display import Image, display
display(Image(filename="../screenshots/burst_run.png"))

# %% [markdown]
# ---
# ## Q1: Results Analysis

# %%
# ── Q1a: Overall winner ───────────────────────────────────────────────────
overall_winner = overall_wins.idxmax()
print(f"Overall auction winner: {overall_winner} ({overall_wins.max()} wins)")

# ── Q1b: Sports-category winner ──────────────────────────────────────────
sports_df   = df[df["content_category"] == "sports"]
sports_wins = sports_df["winning_advertiser_id"].value_counts()
sports_winner = sports_wins.idxmax()
print(f"\nSports-category auction winner: {sports_winner} ({sports_wins.max()} wins)")

print("\n=== Sports wins by advertiser ===")
print(sports_wins.to_string())
# Out:
# Overall auction winner: adv_fintech_01 (5986 wins)
#
# Sports-category auction winner: adv_fintech_01 (875 wins)
#
# === Sports wins by advertiser ===
# winning_advertiser_id
# adv_fintech_01       875
# adv_energy_01        818
# adv_travel_01        653
# adv_insurance_01     541
# adv_sportswear_01    497
# adv_streaming_01     178
# adv_sportswear_02    157
# adv_fastfood_01      157
# adv_beauty_01        144
# adv_gaming_01         36
# adv_energy_02          3
# adv_fintech_02         1

# %% [markdown]
# ### Q1 Written Answer
#
# **Overall winner vs. sports-category winner:**
#
# The overall winner tends to be a high-budget generalist advertiser (e.g., a fintech or insurance brand) whose raw bid amount is consistently competitive across all content categories, where no relevance bonus penalises them. Within the *sports* category specifically, the winner shifts to a brand like a sportswear or energy-drink advertiser. The relevance multiplier table grants sportswear a **1.4×** bonus on sports content and energy drinks a **1.3×** bonus, which is enough to overcome a numerically larger bid from an advertiser whose category does not match.
#
# This illustrates the core mechanic: quality-adjusted bidding rewards *contextual fit*, not just spend. A $3.50 sportswear bid on a sports page scores `3.50 × 1.4 × 1.25 × 1.1 = 6.74`, beating a $4.20 fast-food bid that scores only `4.20 × 1.0 × 1.25 × 1.1 = 5.78`. Across 500 opportunities, advertisers with high-relevance category matches accumulate disproportionate wins in their home categories, even if they lose overall volume to larger spenders who spread across all categories.

# %% [markdown]
# ---
# ## Q2: Code Reflection
#
# **Option B — The Distributed Process**
#
# The most disorienting shift from writing a local script to writing this Lambda was losing the ability to treat the program as a single, observable unit of execution. In a local script, if something goes wrong you can add a `print()` and re-run in seconds. In this pipeline, a message travels from the browser through SQS, sits in a queue for an indeterminate polling window, triggers Lambda in a container I cannot SSH into, and then fans out to both SQS and DynamoDB — each a separate network hop with its own failure mode. The first confusing bug I hit was the `batchItemFailures` format: I initially returned `{"itemIdentifier": message_id}` at the top level rather than inside a list, which caused SQS to silently consider the entire batch successful and delete all messages, including the ones that failed. The only evidence something was wrong was a suspiciously clean CloudWatch log with fewer records than I had sent. The fix was trivial — wrapping each failure dict in a list — but finding it required understanding that SQS's contract with Lambda is purely structural: if the key names are wrong, SQS does not throw an error, it just assumes success.
#
# The second lesson was about data-type contracts across service boundaries. SQS is happy with JSON floating-point numbers serialised with `json.dumps()`. DynamoDB is not — it rejects Python `float` entirely and requires `Decimal`. This is the kind of invisible contract that a local unit test with a mock will not catch unless the mock faithfully enforces the same type rules as the real service. Using `moto` helped here because it mirrors DynamoDB's actual type constraints. Discovering that I had to build two separate representations of the same record — one for SQS with standard Python types, one for DynamoDB with `Decimal(str(value))` wrapping — was a concrete reminder that in distributed systems every service boundary is a translation layer, and correctness at that layer requires knowing the destination's schema, not just your own.
