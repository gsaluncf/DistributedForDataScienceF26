# %% [markdown]
# # Part 5: The Analyst Report
#
# After you have successfully deployed your pipeline and run the **Burst** profile (500 messages) in the test apparatus, you need to extract the results and answer a few questions.
#
# We use `boto3` to scan the DynamoDB table, handling pagination automatically, and convert the results into standard Python dictionaries and floats.

# %% [markdown]
# ## Setup: Configure Your Student ID
# Replace `YOURID` below with the exact student ID you used for deployment.

# %%
# %pip install boto3
STUDENT_ID = "yyeh"  # <--- Change this
TABLE_NAME = f"adflow-{STUDENT_ID}-results"
REGION = "us-east-1"
print(f"Target Table: {TABLE_NAME}")
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# Target Table: adflow-yyeh-results

# %% [markdown]
# ## Step 1: Export Data from DynamoDB
# This cell connects to your DynamoDB table, downloads all records, and converts the Decimal values back to standard floats.

# %%
import boto3
from decimal import Decimal
from collections import Counter

# Note: This uses your active AWS credentials (from `aws configure` or exported environment variables)
dynamodb = boto3.resource("dynamodb", region_name=REGION)
table = dynamodb.Table(TABLE_NAME)

results = []
response = table.scan()
results.extend(response.get("Items", []))

# Handle pagination if the table has more than 1 MB of data
while "LastEvaluatedKey" in response:
    response = table.scan(ExclusiveStartKey=response["LastEvaluatedKey"])
    results.extend(response.get("Items", []))

print(f"\nLoaded {len(results)} records from DynamoDB.")

# Convert Decimal types to Python floats for easier math/plotting
for item in results:
    for key in ["winning_bid_amount", "winning_score", "score_margin"]:
        if key in item and isinstance(item[key], Decimal):
            item[key] = float(item[key])

if results:
    print("\nSample record:")
    print(results[0])
# Out:
# Loaded 500 records from DynamoDB.
#
# Sample record:
# {'processed_at': '2026-03-22T19:42:02.007463Z', 'opportunity_id': 'bff00546-23d3-44ef-9616-207f4c52a9a6', 'winning_score': 8.69375, 'score_margin': 1.7437500000000004, 'winning_advertiser_id': 'adv_energy_01', 'winning_bid_amount': 5.35, 'content_category': 'sports'}

# %% [markdown]
# ## Section 1: Pipeline Evidence
# Print the total records and a quick count of auction wins per advertiser across the entire dataset to prove your pipeline successfully routed messages.

# %%
## Section 1: Pipeline Evidence
# Print the total records and a quick count of auction wins per advertiser across the entire dataset to prove your pipeline successfully routed messages.

# Print the total number of records
print(f"Total pipeline records: {len(results)}")
print("-" * 40)

# Compute and print the auction wins per advertiser (overall)
from collections import Counter

# Extract all winning advertiser IDs from the dataset
winners_list = [item.get("winning_advertiser_id") for item in results if item.get("winning_advertiser_id")]

# Count the occurrences of each advertiser
win_counts = Counter(winners_list)

# Print the results sorted from highest to lowest wins
print("Auction Wins per Advertiser:")
for advertiser, count in win_counts.most_common():
    print(f"{advertiser}: {count} wins")
# Out:
# Total pipeline records: 500
# ----------------------------------------
# Auction Wins per Advertiser:
# adv_auto_01: 67 wins
# adv_fintech_01: 59 wins
# adv_insurance_01: 56 wins
# adv_travel_01: 45 wins
# adv_streaming_01: 44 wins
# adv_fastfood_01: 34 wins
# adv_energy_01: 29 wins
# adv_auto_02: 26 wins
# adv_sportswear_01: 25 wins
# adv_fastfood_02: 21 wins
# adv_insurance_02: 18 wins
# adv_beauty_01: 14 wins
# adv_gaming_01: 11 wins
# adv_fintech_02: 11 wins
# adv_telecom_01: 10 wins
# adv_travel_02: 10 wins
# adv_energy_02: 6 wins
# adv_streaming_02: 6 wins
# adv_sportswear_02: 3 wins
# adv_retail_01: 3 wins
# adv_gaming_02: 1 wins
# adv_beauty_02: 1 wins

# %% [markdown]
# **Evidence Requirement:** Don't forget to push a screenshot of the **Test Apparatus** (showing a completed Burst run) to a `screenshots/` directory in this repo when submitting.

# %% [markdown]
# ---
# ## Q1: Results Analysis
#
# **Question:** Which advertiser won the most auctions overall? Which advertiser won the most in the `sports` content category specifically? Why do the overall and sports-specific rankings differ? Explain in 2–3 sentences, referencing the relevance multiplier table.

# %%
# TODO: Find the top winner in the 'sports' category
sports_results = [r for r in results if r.get("content_category") == "sports"]
print(f"Sports records: {len(sports_results)}")

# 1. Calculate the overall winner
overall_counts = Counter(item.get("winning_advertiser_id") for item in results if item.get("winning_advertiser_id"))
overall_winner = overall_counts.most_common(1)[0]
print(f"Overall Winner: {overall_winner[0]} with {overall_winner[1]} wins")

# 2. Calculate the winner specifically for the 'sports' category
sports_counts = Counter(item.get("winning_advertiser_id") for item in results if item.get("content_category") == "sports" and item.get("winning_advertiser_id"))
sports_winner = sports_counts.most_common(1)[0]
print(f"Sports Category Winner: {sports_winner[0]} with {sports_winner[1]} wins")
# Out:
# Sports records: 135
# Overall Winner: adv_auto_01 with 67 wins
# Sports Category Winner: adv_auto_01 with 24 wins

# %% [markdown]
# **Your Answer (Q1):**
#
# In my specific dataset run, adv_auto_01 won both the overall auctions (67 wins) and the sports category (24 wins), likely due to a consistently dominant base bid. However, generally, overall and category-specific rankings are designed to differ because the system calculates the final score by multiplying the base bid by a category-specific relevance multiplier. This mechanism allows advertisers with lower base bids to outcompete higher general bidders in specific categories if they have a strong relevance multiplier, dynamically shifting the rankings based on the content context.

# %% [markdown]
# ---
# ## Q2: Code Reflection
#
# Answer **one** of the following (your choice):
#
# * **Option A (Scale & Limits):** The test apparatus sent messages in small batches. If traffic suddenly spiked from 10 opportunities a second to 10,000 a second, what specific components of our current pipeline (SQS limits, Lambda concurrency, DynamoDB throughput) would become bottlenecks first, and what AWS settings would you adjust to handle the load?
# * **Option B (The Distributed Process):** Writing code for an event-driven, queue-based pipeline is very different from writing a single local script. What was the most challenging part of getting SQS, Lambda, and DynamoDB to communicate correctly, or the most confusing bug you encountered, and what did it teach you about distributed architecture?
#
# A well-argued two-paragraph response is sufficient for either option.

# %% [markdown]
# **Your Answer (Q2):**
#
# If traffic suddenly spiked to 10,000 opportunities per second, Lambda's unreserved concurrency and DynamoDB's Write Capacity Units (WCU) would immediately become the primary bottlenecks. As seen during the Burst profile test, even a sudden influx of 500 messages caused significant queuing delays because Lambda requires time to scale up its execution environments. At a scale of 10,000 messages per second, we would quickly hit the default regional Lambda concurrency limit (typically 1,000), causing the SQS queue to build a massive backlog. Simultaneously, if DynamoDB is using default provisioned settings, this sudden spike in write requests would result in severe throttling and ProvisionedThroughputExceededException errors.
#
# To handle this enterprise-level load, several AWS settings must be adjusted. First, I would switch the DynamoDB billing mode to On-Demand (or configure Auto-Scaling with a high maximum WCU) to seamlessly absorb massive write spikes without manual intervention. For Lambda, I would request a Service Quota increase for regional concurrency and configure Provisioned Concurrency for this specific function to completely eliminate cold starts and keep environments warm. Finally, I would increase the SQS Batch Size (e.g., up to 100) and adjust the Batch Window; this allows a single Lambda invocation to process many more messages simultaneously, drastically reducing the total number of concurrent executions required and improving the pipeline's overall throughput efficiency.
