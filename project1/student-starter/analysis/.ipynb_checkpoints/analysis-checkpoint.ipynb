# %% [markdown]
# # AdFlow Pipeline — Analyst Report
# **Student:** fchiesa
# **Table:** adflow-fchiesa-results
# **Region:** us-east-1

# %% [markdown]
# ## Section 1: Pipeline Evidence

# %%
import boto3
from decimal import Decimal
from collections import Counter

dynamodb = boto3.resource("dynamodb", region_name="us-east-1")
table = dynamodb.Table("adflow-fchiesa-results")

results = []
response = table.scan()
results.extend(response["Items"])

while "LastEvaluatedKey" in response:
    response = table.scan(ExclusiveStartKey=response["LastEvaluatedKey"])
    results.extend(response["Items"])

print(f"Loaded {len(results)} records")

for item in results:
    for key in ["winning_bid_amount", "winning_score", "score_margin"]:
        if key in item:
            item[key] = float(item[key])

# %%
# Wins per advertiser
win_counts = Counter(item["winning_advertiser_id"] for item in results)
print("Auction wins per advertiser:")
for adv, count in win_counts.most_common():
    print(f"  {adv}: {count}")

# %% [markdown]
# ### Test Apparatus Screenshot — Burst Run (500/500)
#
# ![Captura de pantalla 2026-03-22 a la(s) 21.52.01.png](attachment:aad1832c-363d-432b-a226-e0931959ae22.png)

# %% [markdown]
# ## Q1: Results Analysis

# %%
# Overall winner
overall_winner = win_counts.most_common(1)[0]
print(f"Overall most wins: {overall_winner[0]} with {overall_winner[1]} wins")

# Sports-specific winner
sports_results = [item for item in results if item["content_category"] == "sports"]
sports_counts = Counter(item["winning_advertiser_id"] for item in sports_results)
sports_winner = sports_counts.most_common(1)[0]
print(f"Most wins in sports: {sports_winner[0]} with {sports_winner[1]} wins")

print(f"\nTotal sports opportunities: {len(sports_results)}")
print("\nAll sports wins:")
for adv, count in sports_counts.most_common():
    print(f"  {adv}: {count}")

# %% [markdown]
# ### Q1 Answer
#
# The overall and sports-specific rankings differ because of the relevance multiplier in the scoring formula. In sports content, advertisers in the `sportswear` category get a 1.4x multiplier and `energy_drink` gets 1.3x, meaning their effective bid is worth 30–40% more than the raw CPM. So even if another advertiser bids more in dollar terms, a sports-relevant advertiser wins more often in that context. Outside of sports content, those same advertisers lose their bonus and compete on equal footing, which shifts the overall rankings toward advertisers with higher raw bids across all categories.

# %% [markdown]
# ## Q2: Code Reflection
#
# The trickiest part of building this pipeline was dealing with the data type mismatch between SQS and DynamoDB. For the SQS message I could just use `json.dumps()` with normal Python floats. But DynamoDB rejects Python floats entirely — you have to wrap every numeric value in `Decimal(str(value))` before calling `put_item()`. This meant building the result record twice: once for SQS with regular types, then converting the numerics to Decimal for DynamoDB. It's a subtle requirement that's easy to miss and fails silently if you don't test it.
#
# The other thing that took some thought was how `batchItemFailures` interacts with SQS retries. If the Lambda raises an uncaught exception, SQS retries the entire batch — including messages that were already processed successfully, which would create duplicate records in DynamoDB. The fix is wrapping each message in its own `try/except` and collecting only the failed `messageId` values in the return dict. This way one malformed message doesn't poison the rest of the batch, and SQS only retries what actually failed. It's a good illustration of why partial failure handling matters in distributed systems.
